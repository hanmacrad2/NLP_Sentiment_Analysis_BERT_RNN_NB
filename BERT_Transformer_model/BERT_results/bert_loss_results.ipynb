# %%
loss = np.array([0.382, 0.277, 0.209, 0.151, 0.111, 0.084, 0.063, 0.045, 0.035, 0.027, 0.010, 0.017, 0.012, 0.011, 0.008])
epochs = np.arange(1,16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Artificial-Intelligence/BERT_Transformer_model/results.py in <module>
# ----> 1 loss = np.array([0.382, 0.277, 0.209, 0.151, 0.111, 0.084, 0.063, 0.045, 0.035, 0.027, 0.010, 0.017, 0.012, 0.011, 0.008])
#       2 epochs = np.arange(1,16)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
loss = np.array([0.382, 0.277, 0.209, 0.151, 0.111, 0.084, 0.063, 0.045, 0.035, 0.027, 0.010, 0.017, 0.012, 0.011, 0.008])
epochs = np.arange(1,16)

# %%
plt.plot(epochs, loss, '-o')

# %%
plt.plot(epochs, loss, '-o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss plot for BERT model')
# Out:
# Text(0.5, 1.0, 'Loss plot for BERT model')

# %%
plt.plot(epochs, loss, '-o')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss plot for BERT model')
# Out:
# Text(0.5, 1.0, 'Training Loss plot for BERT model')

# %%
plt.plot(epochs, loss, '-o')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('BERT model - Training Loss')
# Out:
# Text(0.5, 1.0, 'BERT model - Training Loss')
